# %%
import requests
import pandas as pd

# %%
r = requests.get('https://www.indexmundi.com/map/?v=35&l=es')

# %%
dfs = pd.read_html('https://www.indexmundi.com/map/?v=35&l=es')
rawdata=dfs[1]
rawdata.to_csv('csvprueba.csv')
rawdata
# Out:
#                        País  VIH/SIDA - habitantes infectados con VIH/SIDA  \
# 0                 Sudáfrica                                        7700000
# 1                Mozambique                                        2200000
# 2                     India                                        2100000
# 3                   Nigeria                                        1900000
# 4                     Kenia                                        1600000
# ..                      ...                                            ...
# 155               Macedonia                                            500
# 156                Jordania                                            500
# 157                   Qatar                                            500
# 158  San Cristóbal y Nieves                                            200
# 159                 Comoras                                            200
#
#       Año
# 0    2018
# 1    2018
# 2    2017
# 3    2018
# ...

# %%
data = pd.read_csv('csvprueba.csv') 
# Preview the first 5 lines of the loaded data 
data
# Out:
#      Unnamed: 0                    País  \
# 0             0               Sudáfrica
# 1             1              Mozambique
# 2             2                   India
# 3             3                 Nigeria
# 4             4                   Kenia
# ..          ...                     ...
# 155         155               Macedonia
# 156         156                Jordania
# 157         157                   Qatar
# 158         158  San Cristóbal y Nieves
# 159         159                 Comoras
#
#      VIH/SIDA - habitantes infectados con VIH/SIDA   Año
# 0                                          7700000  2018
# 1                                          2200000  2018
# 2                                          2100000  2017
# 3                                          1900000  2018
# 4                                          1600000  2018
# ..                                             ...   ...
# 155                                            500  2018
# ...
